# %%
pip install osmnx
# Out:
# Requirement already satisfied: osmnx in c:\Users\carol\AppData\Local\Programs\Python\Python314\Lib\site-packages (2.1.0)
# Requirement already satisfied: geopandas>=1.0.1 in c:\Users\carol\AppData\Local\Programs\Python\Python314\Lib\site-packages (from osmnx) (1.1.3)
# Requirement already satisfied: networkx>=2.5 in c:\Users\carol\AppData\Local\Programs\Python\Python314\Lib\site-packages (from osmnx) (3.6.1)
# Requirement already satisfied: numpy>=1.24 in c:\Users\carol\AppData\Local\Programs\Python\Python314\Lib\site-packages (from osmnx) (2.4.4)
# Requirement already satisfied: pandas>=1.5 in c:\Users\carol\AppData\Local\Programs\Python\Python314\Lib\site-packages (from osmnx) (3.0.2)
# Requirement already satisfied: requests>=2.30 in c:\Users\carol\AppData\Local\Programs\Python\Python314\Lib\site-packages (from osmnx) (2.33.1)
# Requirement already satisfied: shapely>=2.0 in c:\Users\carol\AppData\Local\Programs\Python\Python314\Lib\site-packages (from osmnx) (2.1.2)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\Users\carol\AppData\Local\Programs\Python\Python314\Lib\site-packages (from geopandas>=1.0.1->osmnx) (0.12.1)
# Requirement already satisfied: packaging in C:\Users\carol\AppData\Roaming\Python\Python314\site-packages (from geopandas>=1.0.1->osmnx) (26.1)
# Requirement already satisfied: pyproj>=3.5.0 in c:\Users\carol\AppData\Local\Programs\Python\Python314\Lib\site-packages (from geopandas>=1.0.1->osmnx) (3.7.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\carol\AppData\Roaming\Python\Python314\site-packages (from pandas>=1.5->osmnx) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\carol\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas>=1.5->osmnx) (2026.1)
# Requirement already satisfied: certifi in c:\Users\carol\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pyogrio>=0.7.2->geopandas>=1.0.1->osmnx) (2026.2.25)
# Requirement already satisfied: six>=1.5 in C:\Users\carol\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.8.2->pandas>=1.5->osmnx) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\carol\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests>=2.30->osmnx) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\carol\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests>=2.30->osmnx) (3.12)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\carol\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests>=2.30->osmnx) (2.6.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
 # Instalação e importação das bibliotecas necessárias

# %pip install osmnx networkx geopandas shapely matplotlib folium scipy

import geopandas as gpd
import pandas as pd
import numpy as np
import networkx as nx
import osmnx as ox
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from shapely.geometry import Point, MultiPoint, Polygon, MultiPolygon
from shapely.ops import unary_union, voronoi_diagram
from scipy.spatial import Voronoi
import warnings
warnings.filterwarnings('ignore')

# %%
# Configuração

# Caminho para o ficheiro com os PTD (GeoPackage ou Shapefile)
# Deve ter uma coluna de geometria (pontos) e uma coluna de ID
CAMINHO_PTD     = rCAMINHO_PTD = r"C:\Users\carol\OneDrive\Desktop\Carolina\Carolina\raw\postos-transformacao-distribuicao.shp"
CAMINHO_OUTPUT  = r"C:\Users\carol\OneDrive\Desktop\Carolina\Carolina\processed\\"

# Coluna com o ID único do PTD no teu ficheiro
COL_ID_PTD = "id"   # ajustar conforme o teu ficheiro

# Zona de estudo — nome para o OSMnx descarregar a rede de ruas
# Podes usar o nome da cidade ou uma lista de zonas
ZONA_ESTUDO = "Aveiro, Portugal"

# Distância máxima de serviço de cada PTD (metros)
# Para baixa tensão residencial, tipicamente 200-500m de cabo
DISTANCIA_MAX_M = 500

# CRS métrico para Portugal
CRS_METRICO = "EPSG:3763"   # PT-TM06 / ETRS89

print("✓ Configuração carregada.")
# Out:
# ✓ Configuração carregada.

# %%
# BLOCO 2 — Carregar os PTD


print("\nA carregar os PTD...")
gdf_ptd = gpd.read_file(CAMINHO_PTD)

# Garantir CRS geográfico para o OSMnx (precisa de WGS84)
if gdf_ptd.crs is None:
    gdf_ptd = gdf_ptd.set_crs("EPSG:4326")
gdf_ptd_wgs84 = gdf_ptd.to_crs("EPSG:4326")
gdf_ptd_metro = gdf_ptd.to_crs(CRS_METRICO)

print(f"  PTD carregados: {len(gdf_ptd)}")
print(f"  Colunas disponíveis: {gdf_ptd.columns.tolist()}")

# Calcular o bounding box para descarregar só a zona necessária
bbox = gdf_ptd_wgs84.total_bounds   # [minx, miny, maxx, maxy]
print(f"  Área coberta: {bbox}")
# Out:
# A carregar os PTD...
#   PTD carregados: 507
#   Colunas disponíveis: ['Codigo_de_I', 'Distrito', 'Concelho', 'Potencia_in', 'Nivel_de_Ut', 'Tipo_Constr', 'Potencia_Co', 'Numero_de_C', 'Potencia_Ge', 'Numero_de_C', 'Histograma_', 'CodDistrito', 'CodDistrito', 'geometry']
#   Área coberta: [-8.73948453 40.53326695 -8.52748572 40.69879267]

# %%
# Descarregar a rede de ruas (OSMnx)


print("\nA descarregar rede de ruas do OpenStreetMap...")
print("  (Pode demorar 1-2 minutos na primeira execução)")

# Descarregar a rede de ruas completa para a zona
# network_type='all' inclui todas as vias (ruas + caminhos + passagens)
# network_type='drive' inclui apenas vias para veículos
G = ox.graph_from_place(
    ZONA_ESTUDO,
    network_type='all',       # 'all' para incluir ruas pedonais (cabos seguem todas as ruas)
    simplify=True,
    retain_all=False,
    truncate_by_edge=True
)

# Converter para não-dirigido (a corrente elétrica pode ir em ambos os sentidos)
G = G.to_undirected()

print(f"  Nós na rede  : {G.number_of_nodes():,}")
print(f"  Arestas      : {G.number_of_edges():,}")
# Out:
# A descarregar rede de ruas do OpenStreetMap...
#   (Pode demorar 1-2 minutos na primeira execução)
#   Nós na rede  : 9,807
#   Arestas      : 13,830

# %%
# Encontrar o nó da rede mais próximo de cada PTD


print("\nA mapear cada PTD ao nó de rede mais próximo...")

# OSMnx funciona em WGS84 para este passo
ptd_nos = []
for idx, row in gdf_ptd_wgs84.iterrows():
    lat = row.geometry.y
    lon = row.geometry.x
    # Encontrar o nó da rede de ruas mais próximo de cada PTD
    no_mais_proximo = ox.distance.nearest_nodes(G, X=lon, Y=lat)
    ptd_nos.append({
        'ptd_id'         : row[COL_ID_PTD] if COL_ID_PTD in row else idx,
        'no_rede'        : no_mais_proximo,
        'lat'            : lat,
        'lon'            : lon,
        'geometry_wgs84' : row.geometry
    })

df_ptd_nos = pd.DataFrame(ptd_nos)
print(f"  {len(df_ptd_nos)} PTD mapeados a nós da rede.")
# Out:
# A mapear cada PTD ao nó de rede mais próximo...
#   507 PTD mapeados a nós da rede.

# %%
# Algoritmo de Voronoi de Rede
#
# Lógica:
#   Para cada nó da rede de ruas, calcular a distância ao PTD
#   mais próximo (usando Dijkstra de múltiplas origens).
#   O nó é atribuído ao PTD que o alcança com menor distância.


print("\nA calcular Voronoi de rede (distâncias ao longo das ruas)...")
print("  (Este passo pode demorar vários minutos para redes grandes)")

# Dicionário: nó_rede → (ptd_id, distância)
atribuicao_nos = {}

# Lista dos nós de origem (um por PTD)
nos_ptd    = list(df_ptd_nos['no_rede'])
ids_ptd    = list(df_ptd_nos['ptd_id'])

# Para eficiência, usamos Dijkstra de múltiplas origens
# NetworkX não tem multi-source Dijkstra direto com identificação de origem,
# por isso iteramos — mas podemos optimizar para redes grandes.


# Correr Dijkstra de cada PTD e guardar as distâncias
distancias_por_ptd = {}

for i, (no_ptd, id_ptd) in enumerate(zip(nos_ptd, ids_ptd)):
    print(f"  A calcular distâncias do PTD {i+1}/{len(nos_ptd)} (id={id_ptd})...")
    try:
        # Distâncias de curto-caminho deste PTD a todos os nós
        distancias = nx.single_source_dijkstra_path_length(
            G,
            source=no_ptd,
            cutoff=DISTANCIA_MAX_M,    # Só considerar nós até DISTANCIA_MAX_M metros
            weight='length'            # Usar o comprimento real das ruas em metros
        )
        distancias_por_ptd[id_ptd] = distancias
    except nx.NetworkXError as e:
        print(f"    AVISO: PTD {id_ptd} não acessível — {e}")
        distancias_por_ptd[id_ptd] = {}

# Atribuir cada nó ao PTD mais próximo
print("\n  A atribuir cada nó ao PTD mais próximo...")
for no in G.nodes():
    melhor_ptd  = None
    melhor_dist = float('inf')
    for id_ptd, distancias in distancias_por_ptd.items():
        if no in distancias and distancias[no] < melhor_dist:
            melhor_dist = distancias[no]
            melhor_ptd  = id_ptd
    if melhor_ptd is not None:
        atribuicao_nos[no] = {'ptd_id': melhor_ptd, 'distancia_m': melhor_dist}

print(f"  {len(atribuicao_nos):,} nós atribuídos a PTD.")
nos_sem_ptd = G.number_of_nodes() - len(atribuicao_nos)
if nos_sem_ptd > 0:
    print(f"  {nos_sem_ptd:,} nós sem cobertura (fora do raio de {DISTANCIA_MAX_M}m de qualquer PTD)")
# Out:
# A calcular Voronoi de rede (distâncias ao longo das ruas)...
#   (Este passo pode demorar vários minutos para redes grandes)
#   A calcular distâncias do PTD 1/507 (id=0)...
#   A calcular distâncias do PTD 2/507 (id=1)...
#   A calcular distâncias do PTD 3/507 (id=2)...
#   A calcular distâncias do PTD 4/507 (id=3)...
#   A calcular distâncias do PTD 5/507 (id=4)...
#   A calcular distâncias do PTD 6/507 (id=5)...
#   A calcular distâncias do PTD 7/507 (id=6)...
#   A calcular distâncias do PTD 8/507 (id=7)...
#   A calcular distâncias do PTD 9/507 (id=8)...
#   A calcular distâncias do PTD 10/507 (id=9)...
#   A calcular distâncias do PTD 11/507 (id=10)...
#   A calcular distâncias do PTD 12/507 (id=11)...
#   A calcular distâncias do PTD 13/507 (id=12)...
#   A calcular distâncias do PTD 14/507 (id=13)...
#   A calcular distâncias do PTD 15/507 (id=14)...
#   A calcular distâncias do PTD 16/507 (id=15)...
#   A calcular distâncias do PTD 17/507 (id=16)...
#   A calcular distâncias do PTD 18/507 (id=17)...
#   A calcular distâncias do PTD 19/507 (id=18)...
#   A calcular distâncias do PTD 20/507 (id=19)...
#   A calcular distâncias do PTD 21/507 (id=20)...
#   A calcular distâncias do PTD 22/507 (id=21)...
#   A calcular distâncias do PTD 23/507 (id=22)...
#   A calcular distâncias do PTD 24/507 (id=23)...
#   A calcular distâncias do PTD 25/507 (id=24)...
#   A calcular distâncias do PTD 26/507 (id=25)...
#   A calcular distâncias do PTD 27/507 (id=26)...
#   A calcular distâncias do PTD 28/507 (id=27)...
#   A calcular distâncias do PTD 29/507 (id=28)...
#   A calcular distâncias do PTD 30/507 (id=29)...
#   A calcular distâncias do PTD 31/507 (id=30)...
#   A calcular distâncias do PTD 32/507 (id=31)...
#   A calcular distâncias do PTD 33/507 (id=32)...
#   A calcular distâncias do PTD 34/507 (id=33)...
#   A calcular distâncias do PTD 35/507 (id=34)...
#   A calcular distâncias do PTD 36/507 (id=35)...
#   A calcular distâncias do PTD 37/507 (id=36)...
#   A calcular distâncias do PTD 38/507 (id=37)...
#   A calcular distâncias do PTD 39/507 (id=38)...
#   A calcular distâncias do PTD 40/507 (id=39)...
#   A calcular distâncias do PTD 41/507 (id=40)...
#   A calcular distâncias do PTD 42/507 (id=41)...
#   A calcular distâncias do PTD 43/507 (id=42)...
#   A calcular distâncias do PTD 44/507 (id=43)...
#   A calcular distâncias do PTD 45/507 (id=44)...
#   A calcular distâncias do PTD 46/507 (id=45)...
#   A calcular distâncias do PTD 47/507 (id=46)...
#   A calcular distâncias do PTD 48/507 (id=47)...
#   A calcular distâncias do PTD 49/507 (id=48)...
#   A calcular distâncias do PTD 50/507 (id=49)...
#   A calcular distâncias do PTD 51/507 (id=50)...
#   A calcular distâncias do PTD 52/507 (id=51)...
#   A calcular distâncias do PTD 53/507 (id=52)...
#   A calcular distâncias do PTD 54/507 (id=53)...
#   A calcular distâncias do PTD 55/507 (id=54)...
#   A calcular distâncias do PTD 56/507 (id=55)...
#   A calcular distâncias do PTD 57/507 (id=56)...
#   A calcular distâncias do PTD 58/507 (id=57)...
#   A calcular distâncias do PTD 59/507 (id=58)...
#   A calcular distâncias do PTD 60/507 (id=59)...
#   A calcular distâncias do PTD 61/507 (id=60)...
#   A calcular distâncias do PTD 62/507 (id=61)...
#   A calcular distâncias do PTD 63/507 (id=62)...
#   A calcular distâncias do PTD 64/507 (id=63)...
#   A calcular distâncias do PTD 65/507 (id=64)...
#   A calcular distâncias do PTD 66/507 (id=65)...
#   A calcular distâncias do PTD 67/507 (id=66)...
#   A calcular distâncias do PTD 68/507 (id=67)...
#   A calcular distâncias do PTD 69/507 (id=68)...
#   A calcular distâncias do PTD 70/507 (id=69)...
#   A calcular distâncias do PTD 71/507 (id=70)...
#   A calcular distâncias do PTD 72/507 (id=71)...
#   A calcular distâncias do PTD 73/507 (id=72)...
#   A calcular distâncias do PTD 74/507 (id=73)...
#   A calcular distâncias do PTD 75/507 (id=74)...
#   A calcular distâncias do PTD 76/507 (id=75)...
#   A calcular distâncias do PTD 77/507 (id=76)...
#   A calcular distâncias do PTD 78/507 (id=77)...
#   A calcular distâncias do PTD 79/507 (id=78)...
#   A calcular distâncias do PTD 80/507 (id=79)...
#   A calcular distâncias do PTD 81/507 (id=80)...
#   A calcular distâncias do PTD 82/507 (id=81)...
#   A calcular distâncias do PTD 83/507 (id=82)...
#   A calcular distâncias do PTD 84/507 (id=83)...
#   A calcular distâncias do PTD 85/507 (id=84)...
#   A calcular distâncias do PTD 86/507 (id=85)...
#   A calcular distâncias do PTD 87/507 (id=86)...
#   A calcular distâncias do PTD 88/507 (id=87)...
#   A calcular distâncias do PTD 89/507 (id=88)...
#   A calcular distâncias do PTD 90/507 (id=89)...
#   A calcular distâncias do PTD 91/507 (id=90)...
#   A calcular distâncias do PTD 92/507 (id=91)...
#   A calcular distâncias do PTD 93/507 (id=92)...
#   A calcular distâncias do PTD 94/507 (id=93)...
#   A calcular distâncias do PTD 95/507 (id=94)...
#   A calcular distâncias do PTD 96/507 (id=95)...
#   A calcular distâncias do PTD 97/507 (id=96)...
#   A calcular distâncias do PTD 98/507 (id=97)...
#   A calcular distâncias do PTD 99/507 (id=98)...
#   A calcular distâncias do PTD 100/507 (id=99)...
#   A calcular distâncias do PTD 101/507 (id=100)...
#   A calcular distâncias do PTD 102/507 (id=101)...
#   A calcular distâncias do PTD 103/507 (id=102)...
#   A calcular distâncias do PTD 104/507 (id=103)...
#   A calcular distâncias do PTD 105/507 (id=104)...
#   A calcular distâncias do PTD 106/507 (id=105)...
#   A calcular distâncias do PTD 107/507 (id=106)...
#   A calcular distâncias do PTD 108/507 (id=107)...
#   A calcular distâncias do PTD 109/507 (id=108)...
#   A calcular distâncias do PTD 110/507 (id=109)...
#   A calcular distâncias do PTD 111/507 (id=110)...
#   A calcular distâncias do PTD 112/507 (id=111)...
#   A calcular distâncias do PTD 113/507 (id=112)...
#   A calcular distâncias do PTD 114/507 (id=113)...
#   A calcular distâncias do PTD 115/507 (id=114)...
#   A calcular distâncias do PTD 116/507 (id=115)...
#   A calcular distâncias do PTD 117/507 (id=116)...
#   A calcular distâncias do PTD 118/507 (id=117)...
#   A calcular distâncias do PTD 119/507 (id=118)...
#   A calcular distâncias do PTD 120/507 (id=119)...
#   A calcular distâncias do PTD 121/507 (id=120)...
#   A calcular distâncias do PTD 122/507 (id=121)...
#   A calcular distâncias do PTD 123/507 (id=122)...
#   A calcular distâncias do PTD 124/507 (id=123)...
#   A calcular distâncias do PTD 125/507 (id=124)...
#   A calcular distâncias do PTD 126/507 (id=125)...
#   A calcular distâncias do PTD 127/507 (id=126)...
#   A calcular distâncias do PTD 128/507 (id=127)...
#   A calcular distâncias do PTD 129/507 (id=128)...
#   A calcular distâncias do PTD 130/507 (id=129)...
#   A calcular distâncias do PTD 131/507 (id=130)...
#   A calcular distâncias do PTD 132/507 (id=131)...
#   A calcular distâncias do PTD 133/507 (id=132)...
#   A calcular distâncias do PTD 134/507 (id=133)...
#   A calcular distâncias do PTD 135/507 (id=134)...
#   A calcular distâncias do PTD 136/507 (id=135)...
#   A calcular distâncias do PTD 137/507 (id=136)...
#   A calcular distâncias do PTD 138/507 (id=137)...
#   A calcular distâncias do PTD 139/507 (id=138)...
#   A calcular distâncias do PTD 140/507 (id=139)...
#   A calcular distâncias do PTD 141/507 (id=140)...
#   A calcular distâncias do PTD 142/507 (id=141)...
#   A calcular distâncias do PTD 143/507 (id=142)...
#   A calcular distâncias do PTD 144/507 (id=143)...
#   A calcular distâncias do PTD 145/507 (id=144)...
#   A calcular distâncias do PTD 146/507 (id=145)...
#   A calcular distâncias do PTD 147/507 (id=146)...
#   A calcular distâncias do PTD 148/507 (id=147)...
#   A calcular distâncias do PTD 149/507 (id=148)...
#   A calcular distâncias do PTD 150/507 (id=149)...
#   A calcular distâncias do PTD 151/507 (id=150)...
#   A calcular distâncias do PTD 152/507 (id=151)...
#   A calcular distâncias do PTD 153/507 (id=152)...
#   A calcular distâncias do PTD 154/507 (id=153)...
#   A calcular distâncias do PTD 155/507 (id=154)...
#   A calcular distâncias do PTD 156/507 (id=155)...
#   A calcular distâncias do PTD 157/507 (id=156)...
#   A calcular distâncias do PTD 158/507 (id=157)...
#   A calcular distâncias do PTD 159/507 (id=158)...
#   A calcular distâncias do PTD 160/507 (id=159)...
#   A calcular distâncias do PTD 161/507 (id=160)...
#   A calcular distâncias do PTD 162/507 (id=161)...
#   A calcular distâncias do PTD 163/507 (id=162)...
#   A calcular distâncias do PTD 164/507 (id=163)...
#   A calcular distâncias do PTD 165/507 (id=164)...
#   A calcular distâncias do PTD 166/507 (id=165)...
#   A calcular distâncias do PTD 167/507 (id=166)...
#   A calcular distâncias do PTD 168/507 (id=167)...
#   A calcular distâncias do PTD 169/507 (id=168)...
#   A calcular distâncias do PTD 170/507 (id=169)...
#   A calcular distâncias do PTD 171/507 (id=170)...
#   A calcular distâncias do PTD 172/507 (id=171)...
#   A calcular distâncias do PTD 173/507 (id=172)...
#   A calcular distâncias do PTD 174/507 (id=173)...
#   A calcular distâncias do PTD 175/507 (id=174)...
#   A calcular distâncias do PTD 176/507 (id=175)...
#   A calcular distâncias do PTD 177/507 (id=176)...
#   A calcular distâncias do PTD 178/507 (id=177)...
#   A calcular distâncias do PTD 179/507 (id=178)...
#   A calcular distâncias do PTD 180/507 (id=179)...
#   A calcular distâncias do PTD 181/507 (id=180)...
#   A calcular distâncias do PTD 182/507 (id=181)...
#   A calcular distâncias do PTD 183/507 (id=182)...
#   A calcular distâncias do PTD 184/507 (id=183)...
#   A calcular distâncias do PTD 185/507 (id=184)...
#   A calcular distâncias do PTD 186/507 (id=185)...
#   A calcular distâncias do PTD 187/507 (id=186)...
#   A calcular distâncias do PTD 188/507 (id=187)...
#   A calcular distâncias do PTD 189/507 (id=188)...
#   A calcular distâncias do PTD 190/507 (id=189)...
#   A calcular distâncias do PTD 191/507 (id=190)...
#   A calcular distâncias do PTD 192/507 (id=191)...
#   A calcular distâncias do PTD 193/507 (id=192)...
#   A calcular distâncias do PTD 194/507 (id=193)...
#   A calcular distâncias do PTD 195/507 (id=194)...
#   A calcular distâncias do PTD 196/507 (id=195)...
#   A calcular distâncias do PTD 197/507 (id=196)...
#   A calcular distâncias do PTD 198/507 (id=197)...
#   A calcular distâncias do PTD 199/507 (id=198)...
#   A calcular distâncias do PTD 200/507 (id=199)...
#   A calcular distâncias do PTD 201/507 (id=200)...
#   A calcular distâncias do PTD 202/507 (id=201)...
#   A calcular distâncias do PTD 203/507 (id=202)...
#   A calcular distâncias do PTD 204/507 (id=203)...
#   A calcular distâncias do PTD 205/507 (id=204)...
#   A calcular distâncias do PTD 206/507 (id=205)...
#   A calcular distâncias do PTD 207/507 (id=206)...
#   A calcular distâncias do PTD 208/507 (id=207)...
#   A calcular distâncias do PTD 209/507 (id=208)...
#   A calcular distâncias do PTD 210/507 (id=209)...
#   A calcular distâncias do PTD 211/507 (id=210)...
#   A calcular distâncias do PTD 212/507 (id=211)...
#   A calcular distâncias do PTD 213/507 (id=212)...
#   A calcular distâncias do PTD 214/507 (id=213)...
#   A calcular distâncias do PTD 215/507 (id=214)...
#   A calcular distâncias do PTD 216/507 (id=215)...
#   A calcular distâncias do PTD 217/507 (id=216)...
#   A calcular distâncias do PTD 218/507 (id=217)...
#   A calcular distâncias do PTD 219/507 (id=218)...
#   A calcular distâncias do PTD 220/507 (id=219)...
#   A calcular distâncias do PTD 221/507 (id=220)...
#   A calcular distâncias do PTD 222/507 (id=221)...
#   A calcular distâncias do PTD 223/507 (id=222)...
#   A calcular distâncias do PTD 224/507 (id=223)...
#   A calcular distâncias do PTD 225/507 (id=224)...
#   A calcular distâncias do PTD 226/507 (id=225)...
#   A calcular distâncias do PTD 227/507 (id=226)...
#   A calcular distâncias do PTD 228/507 (id=227)...
#   A calcular distâncias do PTD 229/507 (id=228)...
#   A calcular distâncias do PTD 230/507 (id=229)...
#   A calcular distâncias do PTD 231/507 (id=230)...
#   A calcular distâncias do PTD 232/507 (id=231)...
#   A calcular distâncias do PTD 233/507 (id=232)...
#   A calcular distâncias do PTD 234/507 (id=233)...
#   A calcular distâncias do PTD 235/507 (id=234)...
#   A calcular distâncias do PTD 236/507 (id=235)...
#   A calcular distâncias do PTD 237/507 (id=236)...
#   A calcular distâncias do PTD 238/507 (id=237)...
#   A calcular distâncias do PTD 239/507 (id=238)...
#   A calcular distâncias do PTD 240/507 (id=239)...
#   A calcular distâncias do PTD 241/507 (id=240)...
#   A calcular distâncias do PTD 242/507 (id=241)...
#   A calcular distâncias do PTD 243/507 (id=242)...
#   A calcular distâncias do PTD 244/507 (id=243)...
#   A calcular distâncias do PTD 245/507 (id=244)...
#   A calcular distâncias do PTD 246/507 (id=245)...
#   A calcular distâncias do PTD 247/507 (id=246)...
#   A calcular distâncias do PTD 248/507 (id=247)...
#   A calcular distâncias do PTD 249/507 (id=248)...
#   A calcular distâncias do PTD 250/507 (id=249)...
#   A calcular distâncias do PTD 251/507 (id=250)...
#   A calcular distâncias do PTD 252/507 (id=251)...
#   A calcular distâncias do PTD 253/507 (id=252)...
#   A calcular distâncias do PTD 254/507 (id=253)...
#   A calcular distâncias do PTD 255/507 (id=254)...
#   A calcular distâncias do PTD 256/507 (id=255)...
#   A calcular distâncias do PTD 257/507 (id=256)...
#   A calcular distâncias do PTD 258/507 (id=257)...
#   A calcular distâncias do PTD 259/507 (id=258)...
#   A calcular distâncias do PTD 260/507 (id=259)...
#   A calcular distâncias do PTD 261/507 (id=260)...
#   A calcular distâncias do PTD 262/507 (id=261)...
#   A calcular distâncias do PTD 263/507 (id=262)...
#   A calcular distâncias do PTD 264/507 (id=263)...
#   A calcular distâncias do PTD 265/507 (id=264)...
#   A calcular distâncias do PTD 266/507 (id=265)...
#   A calcular distâncias do PTD 267/507 (id=266)...
#   A calcular distâncias do PTD 268/507 (id=267)...
#   A calcular distâncias do PTD 269/507 (id=268)...
#   A calcular distâncias do PTD 270/507 (id=269)...
#   A calcular distâncias do PTD 271/507 (id=270)...
#   A calcular distâncias do PTD 272/507 (id=271)...
#   A calcular distâncias do PTD 273/507 (id=272)...
#   A calcular distâncias do PTD 274/507 (id=273)...
#   A calcular distâncias do PTD 275/507 (id=274)...
#   A calcular distâncias do PTD 276/507 (id=275)...
#   A calcular distâncias do PTD 277/507 (id=276)...
#   A calcular distâncias do PTD 278/507 (id=277)...
#   A calcular distâncias do PTD 279/507 (id=278)...
#   A calcular distâncias do PTD 280/507 (id=279)...
#   A calcular distâncias do PTD 281/507 (id=280)...
#   A calcular distâncias do PTD 282/507 (id=281)...
#   A calcular distâncias do PTD 283/507 (id=282)...
#   A calcular distâncias do PTD 284/507 (id=283)...
#   A calcular distâncias do PTD 285/507 (id=284)...
#   A calcular distâncias do PTD 286/507 (id=285)...
#   A calcular distâncias do PTD 287/507 (id=286)...
#   A calcular distâncias do PTD 288/507 (id=287)...
#   A calcular distâncias do PTD 289/507 (id=288)...
#   A calcular distâncias do PTD 290/507 (id=289)...
#   A calcular distâncias do PTD 291/507 (id=290)...
#   A calcular distâncias do PTD 292/507 (id=291)...
#   A calcular distâncias do PTD 293/507 (id=292)...
#   A calcular distâncias do PTD 294/507 (id=293)...
#   A calcular distâncias do PTD 295/507 (id=294)...
#   A calcular distâncias do PTD 296/507 (id=295)...
#   A calcular distâncias do PTD 297/507 (id=296)...
#   A calcular distâncias do PTD 298/507 (id=297)...
#   A calcular distâncias do PTD 299/507 (id=298)...
#   A calcular distâncias do PTD 300/507 (id=299)...
#   A calcular distâncias do PTD 301/507 (id=300)...
#   A calcular distâncias do PTD 302/507 (id=301)...
#   A calcular distâncias do PTD 303/507 (id=302)...
#   A calcular distâncias do PTD 304/507 (id=303)...
#   A calcular distâncias do PTD 305/507 (id=304)...
#   A calcular distâncias do PTD 306/507 (id=305)...
#   A calcular distâncias do PTD 307/507 (id=306)...
#   A calcular distâncias do PTD 308/507 (id=307)...
#   A calcular distâncias do PTD 309/507 (id=308)...
#   A calcular distâncias do PTD 310/507 (id=309)...
#   A calcular distâncias do PTD 311/507 (id=310)...
#   A calcular distâncias do PTD 312/507 (id=311)...
#   A calcular distâncias do PTD 313/507 (id=312)...
#   A calcular distâncias do PTD 314/507 (id=313)...
#   A calcular distâncias do PTD 315/507 (id=314)...
#   A calcular distâncias do PTD 316/507 (id=315)...
#   A calcular distâncias do PTD 317/507 (id=316)...
#   A calcular distâncias do PTD 318/507 (id=317)...
#   A calcular distâncias do PTD 319/507 (id=318)...
#   A calcular distâncias do PTD 320/507 (id=319)...
#   A calcular distâncias do PTD 321/507 (id=320)...
#   A calcular distâncias do PTD 322/507 (id=321)...
#   A calcular distâncias do PTD 323/507 (id=322)...
#   A calcular distâncias do PTD 324/507 (id=323)...
#   A calcular distâncias do PTD 325/507 (id=324)...
#   A calcular distâncias do PTD 326/507 (id=325)...
#   A calcular distâncias do PTD 327/507 (id=326)...
#   A calcular distâncias do PTD 328/507 (id=327)...
#   A calcular distâncias do PTD 329/507 (id=328)...
#   A calcular distâncias do PTD 330/507 (id=329)...
#   A calcular distâncias do PTD 331/507 (id=330)...
#   A calcular distâncias do PTD 332/507 (id=331)...
#   A calcular distâncias do PTD 333/507 (id=332)...
#   A calcular distâncias do PTD 334/507 (id=333)...
#   A calcular distâncias do PTD 335/507 (id=334)...
#   A calcular distâncias do PTD 336/507 (id=335)...
#   A calcular distâncias do PTD 337/507 (id=336)...
#   A calcular distâncias do PTD 338/507 (id=337)...
#   A calcular distâncias do PTD 339/507 (id=338)...
#   A calcular distâncias do PTD 340/507 (id=339)...
#   A calcular distâncias do PTD 341/507 (id=340)...
#   A calcular distâncias do PTD 342/507 (id=341)...
#   A calcular distâncias do PTD 343/507 (id=342)...
#   A calcular distâncias do PTD 344/507 (id=343)...
#   A calcular distâncias do PTD 345/507 (id=344)...
#   A calcular distâncias do PTD 346/507 (id=345)...
#   A calcular distâncias do PTD 347/507 (id=346)...
#   A calcular distâncias do PTD 348/507 (id=347)...
#   A calcular distâncias do PTD 349/507 (id=348)...
#   A calcular distâncias do PTD 350/507 (id=349)...
#   A calcular distâncias do PTD 351/507 (id=350)...
#   A calcular distâncias do PTD 352/507 (id=351)...
#   A calcular distâncias do PTD 353/507 (id=352)...
#   A calcular distâncias do PTD 354/507 (id=353)...
#   A calcular distâncias do PTD 355/507 (id=354)...
#   A calcular distâncias do PTD 356/507 (id=355)...
#   A calcular distâncias do PTD 357/507 (id=356)...
#   A calcular distâncias do PTD 358/507 (id=357)...
#   A calcular distâncias do PTD 359/507 (id=358)...
#   A calcular distâncias do PTD 360/507 (id=359)...
#   A calcular distâncias do PTD 361/507 (id=360)...
#   A calcular distâncias do PTD 362/507 (id=361)...
#   A calcular distâncias do PTD 363/507 (id=362)...
#   A calcular distâncias do PTD 364/507 (id=363)...
#   A calcular distâncias do PTD 365/507 (id=364)...
#   A calcular distâncias do PTD 366/507 (id=365)...
#   A calcular distâncias do PTD 367/507 (id=366)...
#   A calcular distâncias do PTD 368/507 (id=367)...
#   A calcular distâncias do PTD 369/507 (id=368)...
#   A calcular distâncias do PTD 370/507 (id=369)...
#   A calcular distâncias do PTD 371/507 (id=370)...
#   A calcular distâncias do PTD 372/507 (id=371)...
#   A calcular distâncias do PTD 373/507 (id=372)...
#   A calcular distâncias do PTD 374/507 (id=373)...
#   A calcular distâncias do PTD 375/507 (id=374)...
#   A calcular distâncias do PTD 376/507 (id=375)...
#   A calcular distâncias do PTD 377/507 (id=376)...
#   A calcular distâncias do PTD 378/507 (id=377)...
#   A calcular distâncias do PTD 379/507 (id=378)...
#   A calcular distâncias do PTD 380/507 (id=379)...
#   A calcular distâncias do PTD 381/507 (id=380)...
#   A calcular distâncias do PTD 382/507 (id=381)...
#   A calcular distâncias do PTD 383/507 (id=382)...
#   A calcular distâncias do PTD 384/507 (id=383)...
#   A calcular distâncias do PTD 385/507 (id=384)...
#   A calcular distâncias do PTD 386/507 (id=385)...
#   A calcular distâncias do PTD 387/507 (id=386)...
#   A calcular distâncias do PTD 388/507 (id=387)...
#   A calcular distâncias do PTD 389/507 (id=388)...
#   A calcular distâncias do PTD 390/507 (id=389)...
#   A calcular distâncias do PTD 391/507 (id=390)...
#   A calcular distâncias do PTD 392/507 (id=391)...
#   A calcular distâncias do PTD 393/507 (id=392)...
#   A calcular distâncias do PTD 394/507 (id=393)...
#   A calcular distâncias do PTD 395/507 (id=394)...
#   A calcular distâncias do PTD 396/507 (id=395)...
#   A calcular distâncias do PTD 397/507 (id=396)...
#   A calcular distâncias do PTD 398/507 (id=397)...
#   A calcular distâncias do PTD 399/507 (id=398)...
#   A calcular distâncias do PTD 400/507 (id=399)...
#   A calcular distâncias do PTD 401/507 (id=400)...
#   A calcular distâncias do PTD 402/507 (id=401)...
#   A calcular distâncias do PTD 403/507 (id=402)...
#   A calcular distâncias do PTD 404/507 (id=403)...
#   A calcular distâncias do PTD 405/507 (id=404)...
#   A calcular distâncias do PTD 406/507 (id=405)...
#   A calcular distâncias do PTD 407/507 (id=406)...
#   A calcular distâncias do PTD 408/507 (id=407)...
#   A calcular distâncias do PTD 409/507 (id=408)...
#   A calcular distâncias do PTD 410/507 (id=409)...
#   A calcular distâncias do PTD 411/507 (id=410)...
#   A calcular distâncias do PTD 412/507 (id=411)...
#   A calcular distâncias do PTD 413/507 (id=412)...
#   A calcular distâncias do PTD 414/507 (id=413)...
#   A calcular distâncias do PTD 415/507 (id=414)...
#   A calcular distâncias do PTD 416/507 (id=415)...
#   A calcular distâncias do PTD 417/507 (id=416)...
#   A calcular distâncias do PTD 418/507 (id=417)...
#   A calcular distâncias do PTD 419/507 (id=418)...
#   A calcular distâncias do PTD 420/507 (id=419)...
#   A calcular distâncias do PTD 421/507 (id=420)...
#   A calcular distâncias do PTD 422/507 (id=421)...
#   A calcular distâncias do PTD 423/507 (id=422)...
#   A calcular distâncias do PTD 424/507 (id=423)...
#   A calcular distâncias do PTD 425/507 (id=424)...
#   A calcular distâncias do PTD 426/507 (id=425)...
#   A calcular distâncias do PTD 427/507 (id=426)...
#   A calcular distâncias do PTD 428/507 (id=427)...
#   A calcular distâncias do PTD 429/507 (id=428)...
#   A calcular distâncias do PTD 430/507 (id=429)...
#   A calcular distâncias do PTD 431/507 (id=430)...
#   A calcular distâncias do PTD 432/507 (id=431)...
#   A calcular distâncias do PTD 433/507 (id=432)...
#   A calcular distâncias do PTD 434/507 (id=433)...
#   A calcular distâncias do PTD 435/507 (id=434)...
#   A calcular distâncias do PTD 436/507 (id=435)...
#   A calcular distâncias do PTD 437/507 (id=436)...
#   A calcular distâncias do PTD 438/507 (id=437)...
#   A calcular distâncias do PTD 439/507 (id=438)...
#   A calcular distâncias do PTD 440/507 (id=439)...
#   A calcular distâncias do PTD 441/507 (id=440)...
#   A calcular distâncias do PTD 442/507 (id=441)...
#   A calcular distâncias do PTD 443/507 (id=442)...
#   A calcular distâncias do PTD 444/507 (id=443)...
#   A calcular distâncias do PTD 445/507 (id=444)...
#   A calcular distâncias do PTD 446/507 (id=445)...
#   A calcular distâncias do PTD 447/507 (id=446)...
#   A calcular distâncias do PTD 448/507 (id=447)...
#   A calcular distâncias do PTD 449/507 (id=448)...
#   A calcular distâncias do PTD 450/507 (id=449)...
#   A calcular distâncias do PTD 451/507 (id=450)...
#   A calcular distâncias do PTD 452/507 (id=451)...
#   A calcular distâncias do PTD 453/507 (id=452)...
#   A calcular distâncias do PTD 454/507 (id=453)...
#   A calcular distâncias do PTD 455/507 (id=454)...
#   A calcular distâncias do PTD 456/507 (id=455)...
#   A calcular distâncias do PTD 457/507 (id=456)...
#   A calcular distâncias do PTD 458/507 (id=457)...
#   A calcular distâncias do PTD 459/507 (id=458)...
#   A calcular distâncias do PTD 460/507 (id=459)...
#   A calcular distâncias do PTD 461/507 (id=460)...
#   A calcular distâncias do PTD 462/507 (id=461)...
#   A calcular distâncias do PTD 463/507 (id=462)...
#   A calcular distâncias do PTD 464/507 (id=463)...
#   A calcular distâncias do PTD 465/507 (id=464)...
#   A calcular distâncias do PTD 466/507 (id=465)...
#   A calcular distâncias do PTD 467/507 (id=466)...
#   A calcular distâncias do PTD 468/507 (id=467)...
#   A calcular distâncias do PTD 469/507 (id=468)...
#   A calcular distâncias do PTD 470/507 (id=469)...
#   A calcular distâncias do PTD 471/507 (id=470)...
#   A calcular distâncias do PTD 472/507 (id=471)...
#   A calcular distâncias do PTD 473/507 (id=472)...
#   A calcular distâncias do PTD 474/507 (id=473)...
#   A calcular distâncias do PTD 475/507 (id=474)...
#   A calcular distâncias do PTD 476/507 (id=475)...
#   A calcular distâncias do PTD 477/507 (id=476)...
#   A calcular distâncias do PTD 478/507 (id=477)...
#   A calcular distâncias do PTD 479/507 (id=478)...
#   A calcular distâncias do PTD 480/507 (id=479)...
#   A calcular distâncias do PTD 481/507 (id=480)...
#   A calcular distâncias do PTD 482/507 (id=481)...
#   A calcular distâncias do PTD 483/507 (id=482)...
#   A calcular distâncias do PTD 484/507 (id=483)...
#   A calcular distâncias do PTD 485/507 (id=484)...
#   A calcular distâncias do PTD 486/507 (id=485)...
#   A calcular distâncias do PTD 487/507 (id=486)...
#   A calcular distâncias do PTD 488/507 (id=487)...
#   A calcular distâncias do PTD 489/507 (id=488)...
#   A calcular distâncias do PTD 490/507 (id=489)...
#   A calcular distâncias do PTD 491/507 (id=490)...
#   A calcular distâncias do PTD 492/507 (id=491)...
#   A calcular distâncias do PTD 493/507 (id=492)...
#   A calcular distâncias do PTD 494/507 (id=493)...
#   A calcular distâncias do PTD 495/507 (id=494)...
#   A calcular distâncias do PTD 496/507 (id=495)...
#   A calcular distâncias do PTD 497/507 (id=496)...
#   A calcular distâncias do PTD 498/507 (id=497)...
#   A calcular distâncias do PTD 499/507 (id=498)...
#   A calcular distâncias do PTD 500/507 (id=499)...
#   A calcular distâncias do PTD 501/507 (id=500)...
#   A calcular distâncias do PTD 502/507 (id=501)...
#   A calcular distâncias do PTD 503/507 (id=502)...
#   A calcular distâncias do PTD 504/507 (id=503)...
#   A calcular distâncias do PTD 505/507 (id=504)...
#   A calcular distâncias do PTD 506/507 (id=505)...
#   A calcular distâncias do PTD 507/507 (id=506)...
#
#   A atribuir cada nó ao PTD mais próximo...
#   8,233 nós atribuídos a PTD.
#   1,574 nós sem cobertura (fora do raio de 500m de qualquer PTD)

# %%
# Construir os polígonos de área de serviço por PTD

print("\nA construir polígonos de área de serviço...")

import numpy as np

from scipy.spatial import Delaunay
from shapely.geometry import (
    MultiPoint,
    MultiLineString,
    Polygon
)
from shapely.ops import unary_union


# Obter coordenadas de todos os nós
nos_coords = {
    no: (data['x'], data['y'])
    for no, data in G.nodes(data=True)
}


def alpha_shape(points, alpha=0.003):
    """
    Calcula o alpha shape (casco côncavo)
    de um conjunto de pontos.
    """

    # Poucos pontos → convex hull
    if len(points) < 4:
        return MultiPoint(points).convex_hull

    coords = np.array(points)

    try:
        tri = Delaunay(coords)
    except Exception:
        return MultiPoint(points).convex_hull

    triangles = coords[tri.simplices]

    # Comprimento dos lados
    a = np.sqrt(((triangles[:, 0] - triangles[:, 1]) ** 2).sum(axis=1))
    b = np.sqrt(((triangles[:, 1] - triangles[:, 2]) ** 2).sum(axis=1))
    c = np.sqrt(((triangles[:, 2] - triangles[:, 0]) ** 2).sum(axis=1))

    # Semiperímetro
    s = (a + b + c) / 2.0

    # Área dos triângulos
    area = np.sqrt(
        np.maximum(
            s * (s - a) * (s - b) * (s - c),
            0
        )
    )

    # Circunraio
    circum_r = a * b * c / np.where(
        area == 0,
        1e-10,
        4.0 * area
    )

    # Filtrar triângulos válidos
    filtro = circum_r < (1.0 / alpha)

    simplices_filtrados = tri.simplices[filtro]

    # Nenhum triângulo válido
    if len(simplices_filtrados) == 0:
        return MultiPoint(points).convex_hull

    # Criar polígonos dos triângulos
    triangles_polys = [
        Polygon(coords[t])
        for t in simplices_filtrados
    ]

    # Unir todos os triângulos
    resultado = unary_union(triangles_polys)

    return resultado



# Construir polígonos por PTD


areas_servico = []
grupos_nos = {}

# Agrupar nós por PTD
for no, info in atribuicao_nos.items():

    ptd_id = info['ptd_id']

    if ptd_id not in grupos_nos:
        grupos_nos[ptd_id] = []

    grupos_nos[ptd_id].append(nos_coords[no])


# Criar polígonos
for id_ptd, pontos in grupos_nos.items():

    if len(pontos) < 3:
        continue

    try:

        # Alpha shape
        poligono = alpha_shape(
            pontos,
            alpha=0.003
        )

        # Fallback
        if poligono is None or poligono.is_empty:
            poligono = MultiPoint(pontos).convex_hull

        areas_servico.append({
            'ptd_id': id_ptd,
            'n_nos': len(pontos),
            'geometry': poligono
        })

    except Exception as e:

        print(
            f"  AVISO: Erro ao criar polígono "
            f"para PTD {id_ptd}: {e}"
        )

print(f"  {len(areas_servico)} áreas de serviço criadas.")
# Out:
# A construir polígonos de área de serviço...
#   459 áreas de serviço criadas.

# %%
# Criar GeoDataFrame das áreas de serviço


gdf_areas = gpd.GeoDataFrame(areas_servico, crs="EPSG:4326")
gdf_areas = gdf_areas.to_crs(CRS_METRICO)

# Juntar atributos dos PTD originais
gdf_ptd_attrs = gdf_ptd.copy()
if COL_ID_PTD in gdf_ptd_attrs.columns:
    gdf_ptd_attrs = gdf_ptd_attrs.rename(columns={'geometry': 'geometry_ptd'})
    gdf_ptd_attrs = gdf_ptd_attrs.set_geometry('geometry_ptd')
    try:
        gdf_areas = gdf_areas.merge(
            gdf_ptd_attrs[[COL_ID_PTD]].rename(columns={COL_ID_PTD: 'ptd_id'}),
            on='ptd_id', how='left'
        )
    except Exception:
        pass

# Calcular área de cada zona de serviço
gdf_areas['area_km2'] = gdf_areas.geometry.area / 1e6

print(f"\n--- RESUMO DAS ÁREAS DE SERVIÇO ---")
print(f"  Nº de áreas criadas  : {len(gdf_areas)}")
print(f"  Área média (km²)     : {gdf_areas['area_km2'].mean():.3f}")
print(f"  Área total (km²)     : {gdf_areas['area_km2'].sum():.3f}")

# Exportar
gdf_areas.to_file(CAMINHO_OUTPUT + 'PTD_Areas_Servico_Rede.gpkg', driver='GPKG')
print("✓ Áreas de serviço exportadas → PTD_Areas_Servico_Rede.gpkg")
# Out:
# --- RESUMO DAS ÁREAS DE SERVIÇO ---
#   Nº de áreas criadas  : 459
#   Área média (km²)     : 0.052
#   Área total (km²)     : 23.820
# ✓ Áreas de serviço exportadas → PTD_Areas_Servico_Rede.gpkg

# %%
# Atribuir cada edifício ao seu PTD por rede


print("\nA atribuir edifícios ao PTD mais próximo por rede...")

# Carregar edifícios (hotspots ou todos)
try:
    gdf_edificios = gpd.read_file(CAMINHO_OUTPUT + 'Edificios_Hotspots_CER.gpkg')
    print("  A usar edifícios hotspot.")
except FileNotFoundError:
    gdf_edificios = gpd.read_file(
        r"C:\Users\carol\OneDrive\Desktop\Carolina\Carolina\raw\MstCSCS_Sem_2526.gpkg",
        layer='postal_code_buildings_assigned'
    )
    print("  A usar todos os edifícios.")

gdf_edificios = gdf_edificios.to_crs(CRS_METRICO)

# Spatial join: cada edifício herda o PTD da área em que cai
gdf_edificios_ptd = gpd.sjoin(
    gdf_edificios,
    gdf_areas[['ptd_id', 'geometry']],
    how='left',
    predicate='intersects'
)
gdf_edificios_ptd = gdf_edificios_ptd.drop(columns=['index_right'], errors='ignore')

sem_ptd = gdf_edificios_ptd['ptd_id'].isna().sum()
print(f"  Edifícios com PTD atribuído: {(~gdf_edificios_ptd['ptd_id'].isna()).sum():,}")
print(f"  Edifícios sem PTD (fora do raio): {sem_ptd:,}")

gdf_edificios_ptd.to_file(CAMINHO_OUTPUT + 'Edificios_com_PTD_Rede.gpkg', driver='GPKG')
print("✓ Edifícios com PTD exportados → Edificios_com_PTD_Rede.gpkg")
# Out:
# A atribuir edifícios ao PTD mais próximo por rede...
#   A usar edifícios hotspot.
#   Edifícios com PTD atribuído: 278
#   Edifícios sem PTD (fora do raio): 191
# ✓ Edifícios com PTD exportados → Edificios_com_PTD_Rede.gpkg

# %%
# Visualização estática


print("\nA gerar mapa das áreas de serviço...")

fig, ax = plt.subplots(figsize=(14, 12))
fig.patch.set_facecolor('#F8F8F6')
ax.set_facecolor('#F8F8F6')

# Gerar cores distintas por PTD
n_ptds  = len(gdf_areas)
cmap    = plt.cm.get_cmap('tab20', n_ptds)
cores   = [mcolors.to_hex(cmap(i)) for i in range(n_ptds)]

# Desenhar cada área de serviço com cor distinta
for i, (_, row) in enumerate(gdf_areas.iterrows()):
    gpd.GeoDataFrame([row], crs=CRS_METRICO).plot(
        ax=ax,
        color=cores[i % len(cores)],
        alpha=0.45,
        edgecolor='white',
        linewidth=0.8
    )

# Desenhar os PTD como estrelas vermelhas
gdf_ptd_metro.plot(
    ax=ax,
    color='#E24B4A',
    markersize=80,
    marker='*',
    zorder=5,
    label='PTD E-Redes'
)

# Anotações dos PTD (opcional — pode ficar sobrelotado com muitos PTD)
# for _, row in gdf_ptd_metro.iterrows():
#     ax.annotate(str(row[COL_ID_PTD]),
#                 xy=(row.geometry.x, row.geometry.y),
#                 fontsize=6, color='black', ha='center')

plt.title(
    f'Áreas de Serviço dos PTD — Voronoi de Rede\n'
    f'Distância máx.: {DISTANCIA_MAX_M}m | {len(gdf_areas)} PTD | Aveiro',
    fontsize=13, fontweight='bold', color='#0F2D4A'
)
plt.axis('off')
plt.legend(loc='lower right', fontsize=10)

plt.tight_layout()
plt.savefig(CAMINHO_OUTPUT + 'mapa_voronoi_rede_PTD.png', dpi=150, bbox_inches='tight')
plt.show()
print("✓ Mapa guardado → mapa_voronoi_rede_PTD.png")
# Out:
# A gerar mapa das áreas de serviço...
# ✓ Mapa guardado → mapa_voronoi_rede_PTD.png

# %%
# Visualização interativa (Folium)

print("\nA gerar mapa interativo...")
import folium
import branca.colormap as cm

# Centro do mapa
centro_lat = gdf_ptd_wgs84.geometry.y.mean()
centro_lon = gdf_ptd_wgs84.geometry.x.mean()

m = folium.Map(
    location=[centro_lat, centro_lon],
    zoom_start=13,
    tiles='CartoDB positron'
)

# Converter áreas para WGS84 para o Folium
gdf_areas_wgs = gdf_areas.to_crs("EPSG:4326")

# Desenhar áreas de serviço
for i, (_, row) in enumerate(gdf_areas_wgs.iterrows()):
    if row.geometry is None or row.geometry.is_empty:
        continue
    cor = cores[i % len(cores)]
    folium.GeoJson(
        data=gpd.GeoDataFrame([row], crs="EPSG:4326").__geo_interface__,
        style_function=lambda x, c=cor: {
            'fillColor'  : c,
            'color'      : '#ffffff',
            'weight'     : 1,
            'fillOpacity': 0.45
        },
        tooltip=folium.GeoJsonTooltip(
            fields=['ptd_id', 'n_nos', 'area_km2'],
            aliases=['PTD ID:', 'Nós da rede:', 'Área (km²):'],
            style="font-size:12px;"
        )
    ).add_to(m)

# Desenhar PTD como marcadores
for _, row in gdf_ptd_wgs84.iterrows():
    folium.Marker(
        location=[row.geometry.y, row.geometry.x],
        tooltip=f"PTD: {row[COL_ID_PTD] if COL_ID_PTD in row else 'N/A'}",
        icon=folium.Icon(color='red', icon='bolt', prefix='fa')
    ).add_to(m)

folium.LayerControl().add_to(m)
m.save(CAMINHO_OUTPUT + 'mapa_voronoi_rede_PTD.html')
print("✓ Mapa interativo guardado → mapa_voronoi_rede_PTD.html")
# Out:
# A gerar mapa interativo...
# ✓ Mapa interativo guardado → mapa_voronoi_rede_PTD.html

# %%
"""
Voronoi de Rede — Áreas de Influência dos PTD usando Ruas
Projeto CER Aveiro

Calcula as áreas de serviço de cada Posto de Transformação de Distribuição (PTD)
usando a rede de ruas real em vez de distância euclidiana (Voronoi geométrico).

Bibliotecas necessárias:
    pip install osmnx networkx geopandas shapely matplotlib folium scipy
"""


# Validação: comparar Voronoi de rede vs Euclidiano


print("\nA calcular Voronoi Euclidiano para comparação...")

from scipy.spatial import Voronoi as ScipyVoronoi
from shapely.ops import voronoi_diagram as shapely_voronoi

# Voronoi euclidiano com Shapely
pontos_ptd  = MultiPoint([row.geometry for _, row in gdf_ptd_metro.iterrows()])
regiao_total = gdf_areas.unary_union.convex_hull.buffer(500)

vor_euclid   = shapely_voronoi(pontos_ptd, envelope=regiao_total)
gdf_vor_euclid = gpd.GeoDataFrame(
    geometry=list(vor_euclid.geoms),
    crs=CRS_METRICO
)

# Comparação visual lado a lado
fig, axes = plt.subplots(1, 2, figsize=(18, 8))
fig.patch.set_facecolor('#F8F8F6')

# Voronoi euclidiano
for i, (_, row) in enumerate(gdf_vor_euclid.iterrows()):
    gpd.GeoDataFrame([row], crs=CRS_METRICO).plot(
        ax=axes[0], color=cores[i % len(cores)], alpha=0.5,
        edgecolor='white', linewidth=0.8
    )
gdf_ptd_metro.plot(ax=axes[0], color='red', markersize=60, marker='*', zorder=5)
axes[0].set_title('Voronoi Euclidiano\n(distância em linha reta)', fontsize=12, fontweight='bold')
axes[0].axis('off')

# Voronoi de rede
for i, (_, row) in enumerate(gdf_areas.iterrows()):
    gpd.GeoDataFrame([row], crs=CRS_METRICO).plot(
        ax=axes[1], color=cores[i % len(cores)], alpha=0.5,
        edgecolor='white', linewidth=0.8
    )
gdf_ptd_metro.plot(ax=axes[1], color='red', markersize=60, marker='*', zorder=5)
axes[1].set_title(f'Voronoi de Rede (este trabalho)\n(distância pelas ruas, raio {DISTANCIA_MAX_M}m)',
                  fontsize=12, fontweight='bold', color='#0D9488')
axes[1].axis('off')

plt.suptitle('Comparação: Voronoi Euclidiano vs Voronoi de Rede',
             fontsize=14, fontweight='bold', color='#0F2D4A')
plt.tight_layout()
plt.savefig(CAMINHO_OUTPUT + 'comparacao_voronoi_euclid_vs_rede.png', dpi=150, bbox_inches='tight')
plt.show()
print("✓ Comparação guardada → comparacao_voronoi_euclid_vs_rede.png")

print("\n" + "="*55)
print("  Pipeline Voronoi de Rede concluído!")
print("="*55)
print(f"  Ficheiros gerados em: {CAMINHO_OUTPUT}")
print("  - PTD_Areas_Servico_Rede.gpkg      (áreas de serviço)")
print("  - Edificios_com_PTD_Rede.gpkg      (edifícios + PTD atribuído)")
print("  - mapa_voronoi_rede_PTD.png        (mapa estático)")
print("  - mapa_voronoi_rede_PTD.html       (mapa interativo)")
print("  - comparacao_voronoi_euclid_vs_rede.png")
# Out:
# A calcular Voronoi Euclidiano para comparação...
# ✓ Comparação guardada → comparacao_voronoi_euclid_vs_rede.png
#
# =======================================================
#   Pipeline Voronoi de Rede concluído!
# =======================================================
#   Ficheiros gerados em: C:\Users\carol\OneDrive\Desktop\Carolina\Carolina\processed\\
#   - PTD_Areas_Servico_Rede.gpkg      (áreas de serviço)
#   - Edificios_com_PTD_Rede.gpkg      (edifícios + PTD atribuído)
#   - mapa_voronoi_rede_PTD.png        (mapa estático)
#   - mapa_voronoi_rede_PTD.html       (mapa interativo)
#   - comparacao_voronoi_euclid_vs_rede.png
